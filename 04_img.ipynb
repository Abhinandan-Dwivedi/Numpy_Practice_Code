# %%
import numpy as np
import matplotlib.pyplot as plt
a = np.array([4,5,6,7])
np.save('arr.npy', a)
load  = np.load("arr.npy")
# plt.imshow(load)

# %%
from PIL import Image as img 
openimg = img.open('image.png')
arr = np.array(openimg)

plt.imshow(arr)
plt.grid(False)

# %%
# image can be saved as numpy file as array 
np.save('logo.npy' ,arr)
ld = np.load('logo.npy')

plt.imshow(ld)
